# %%
import vega_datasets

# %%
dir(vega_datasets.data)
# Out:
# ['7zip',
#  'airports',
#  'annual_precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2_concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare_dependencies',
#  'flights_10k',
#  'flights_200k',
#  'flights_20k',
#  'flights_2k',
#  'flights_3m',
#  'flights_5k',
#  'flights_airport',
#  'gapminder',
#  'gapminder_health_income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa_electricity',
#  'iris',
#  'jobs',
#  'la_riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal_2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle_temps',
#  'seattle_weather',
#  'sf_temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
# ...

# %%
import pandas as pd

# %%
df=vega_datasets.data.population()

# %%
df
# Out:
#      year  age  sex   people
# 0    1850    0    1  1483789
# 1    1850    0    2  1450376
# 2    1850    5    1  1411067
# 3    1850    5    2  1359668
# 4    1850   10    1  1260099
# ..    ...  ...  ...      ...
# 565  2000   80    2  3221898
# 566  2000   85    1   970357
# 567  2000   85    2  1981156
# 568  2000   90    1   336303
# 569  2000   90    2  1064581
#
# [570 rows x 4 columns]

# %%
df1=vega_datasets.data.population_engineers_hurricanes()

# %%
df1
# Out:
#                    state  id  population  engineers  hurricanes
# 0                Alabama   1     4863300   0.003422          22
# 1                 Alaska   2      741894   0.001591           0
# 2                Arizona   4     6931071   0.004774           0
# 3               Arkansas   5     2988248   0.002440           0
# 4             California   6    39250017   0.007126           0
# 5               Colorado   8     5540545   0.008088           0
# 6            Connecticut   9     3576452   0.005897          10
# 7               Delaware  10      952065   0.004989           2
# 8   District of Columbia  11      681170   0.011759           0
# 9                Florida  12    20612439   0.003300         110
# 10               Georgia  13    10310371   0.004940          20
# 11                Hawaii  15     1428557   0.001624           0
# 12                 Idaho  16     1683140   0.002971           0
# 13              Illinois  17    12801539   0.004478           0
# ...

# %%
df2=vega_datasets.data.seattle_temps()

# %%
df2
# Out:
#                     date  temp
# 0    2010-01-01 00:00:00  39.4
# 1    2010-01-01 01:00:00  39.2
# 2    2010-01-01 02:00:00  39.0
# 3    2010-01-01 03:00:00  38.9
# 4    2010-01-01 04:00:00  38.8
# ...                  ...   ...
# 8754 2010-12-31 19:00:00  40.7
# 8755 2010-12-31 20:00:00  40.5
# 8756 2010-12-31 21:00:00  40.2
# 8757 2010-12-31 22:00:00  40.0
# 8758 2010-12-31 23:00:00  39.6
#
# [8759 rows x 2 columns]

# %%
df3=vega_datasets.data.seattle_weather()

# %%
df3
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02           10.9      10.6       2.8   4.5     rain
# 2    2012-01-03            0.8      11.7       7.2   2.3     rain
# 3    2012-01-04           20.3      12.2       5.6   4.7     rain
# 4    2012-01-05            1.3       8.9       2.8   6.1     rain
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9      fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3      fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df4=vega_datasets.data.sf_temps()

# %%
df4
# Out:
#       temp                date
# 0     47.8 2010-01-01 00:00:00
# 1     47.4 2010-01-01 01:00:00
# 2     46.9 2010-01-01 02:00:00
# 3     46.5 2010-01-01 03:00:00
# 4     46.0 2010-01-01 04:00:00
# ...    ...                 ...
# 8754  50.4 2010-12-31 19:00:00
# 8755  49.9 2010-12-31 20:00:00
# 8756  49.4 2010-12-31 21:00:00
# 8757  48.8 2010-12-31 22:00:00
# 8758  48.3 2010-12-31 23:00:00
#
# [8759 rows x 2 columns]

# %%
df5=vega_datasets.data.sp500()

# %%
df5
# Out:
#           date    price
# 0   2000-01-01  1394.46
# 1   2000-02-01  1366.42
# 2   2000-03-01  1498.58
# 3   2000-04-01  1452.43
# 4   2000-05-01  1420.60
# ..         ...      ...
# 118 2009-11-01  1095.63
# 119 2009-12-01  1115.10
# 120 2010-01-01  1073.87
# 121 2010-02-01  1104.49
# 122 2010-03-01  1140.45
#
# [123 rows x 2 columns]

# %%
df6=vega_datasets.data.stocks()

# %%
df6
# Out:
#     symbol       date   price
# 0     MSFT 2000-01-01   39.81
# 1     MSFT 2000-02-01   36.35
# 2     MSFT 2000-03-01   43.22
# 3     MSFT 2000-04-01   28.37
# 4     MSFT 2000-05-01   25.45
# ..     ...        ...     ...
# 555   AAPL 2009-11-01  199.91
# 556   AAPL 2009-12-01  210.73
# 557   AAPL 2010-01-01  192.06
# 558   AAPL 2010-02-01  204.62
# 559   AAPL 2010-03-01  223.02
#
# [560 rows x 3 columns]

# %%
df7=vega_datasets.data.udistrict()

# %%
df7
# Out:
#           key        lat
# 0    bakeries  47.668870
# 1    bakeries  47.661781
# 2    bakeries  47.659980
# 3    bakeries  47.663373
# 4    bakeries  47.658210
# ..        ...        ...
# 177    coffee  47.654667
# 178    coffee  47.661621
# 179    coffee  47.662790
# 180    coffee  47.656376
# 181    coffee  47.656833
#
# [182 rows x 2 columns]

# %%
df8=vega_datasets.data.unemployment()

# %%
df8
# Out:
#          id   rate
# 0      1001  0.097
# 1      1003  0.091
# 2      1005  0.134
# 3      1007  0.121
# 4      1009  0.099
# ...     ...    ...
# 3213  72145  0.176
# 3214  72147  0.277
# 3215  72149  0.198
# 3216  72151  0.241
# 3217  72153  0.160
#
# [3218 rows x 2 columns]

# %%
df9=vega_datasets.data.weather()

# %%
df9
# Out:
#   day                   record                   normal  \
# 0   M  {'high': 62, 'low': 15}  {'high': 50, 'low': 38}
# 1   T  {'high': 62, 'low': 23}  {'high': 50, 'low': 38}
# 2   W  {'high': 61, 'low': 20}  {'high': 50, 'low': 38}
# 3   T  {'high': 67, 'low': 21}  {'high': 50, 'low': 38}
# 4   F  {'high': 61, 'low': 23}  {'high': 50, 'low': 38}
# 5   S  {'high': 67, 'low': 20}  {'high': 50, 'low': 38}
# 6   S  {'high': 63, 'low': 23}  {'high': 50, 'low': 39}
# 7   M  {'high': 61, 'low': 26}  {'high': 51, 'low': 39}
# 8   T  {'high': 61, 'low': 24}  {'high': 51, 'low': 39}
# 9   W  {'high': 63, 'low': 20}  {'high': 51, 'low': 39}
#
#                     actual  id  \
# 0  {'high': 48, 'low': 36}   0
# 1  {'high': 50, 'low': 40}   1
# 2  {'high': 55, 'low': 36}   2
# 3  {'high': 51, 'low': 33}   3
# 4  {'high': 50, 'low': 30}   4
# 5                      NaN   5
# 6                      NaN   6
# 7                      NaN   7
# 8                      NaN   8
# ...
